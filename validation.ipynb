# %%
import numpy as np

# %%
data = np.load("./dataset/hello/009.npy")

# %%
aa = data.reshape(60, 44, 2)

# %%
frame.shape
# Out:
# (44, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load("./dataset/test/003.npy")
frame = data[0].reshape(44, 2)

uniq, counts = np.unique(frame, axis=0, return_counts=True)
print(list(zip(uniq, counts)))

# 많이 겹치는 점 확인
mask = ~(np.all(frame == frame[0], axis=1))  # 단순 예시
plt.scatter(frame[mask, 0], frame[mask, 1])
plt.gca().invert_yaxis()
plt.show()
# Out:
# [(array([-0.9676534,  0.5144074], dtype=float32), np.int64(1)), (array([-0.961639 ,  0.6198247], dtype=float32), np.int64(1)), (array([-0.9533858,  0.5151737], dtype=float32), np.int64(1)), (array([-0.9422665,  0.5403352], dtype=float32), np.int64(1)), (array([-0.89000714,  0.5792112 ], dtype=float32), np.int64(1)), (array([-0.88606024,  0.45070985], dtype=float32), np.int64(1)), (array([-0.8705883 ,  0.46372032], dtype=float32), np.int64(1)), (array([-0.85828084,  0.5097084 ], dtype=float32), np.int64(1)), (array([-0.83816147,  0.8861787 ], dtype=float32), np.int64(1)), (array([-0.80215025,  0.55690444], dtype=float32), np.int64(1)), (array([-0.80092806,  0.39172745], dtype=float32), np.int64(1)), (array([-0.783854  ,  0.41888034], dtype=float32), np.int64(1)), (array([-0.77264327,  0.48302197], dtype=float32), np.int64(1)), (array([-0.71512765,  0.83464766], dtype=float32), np.int64(1)), (array([-0.7075789,  0.5573991], dtype=float32), np.int64(1)), (array([-0.6907544 ,  0.38347927], dtype=float32), np.int64(1)), (array([-0.6673518 ,  0.39460626], dtype=float32), np.int64(1)), (array([-0.6575733 ,  0.45260492], dtype=float32), np.int64(1)), (array([-0.6032639 ,  0.71495754], dtype=float32), np.int64(1)), (array([-0.5339286 ,  0.60208446], dtype=float32), np.int64(1)), (array([-0.5037312 ,  0.48446918], dtype=float32), np.int64(1)), (array([-0.49998644, -0.00369192], dtype=float32), np.int64(1)), (array([0.3694901 , 0.30693457], dtype=float32), np.int64(1)), (array([0.43078128, 0.38977885], dtype=float32), np.int64(1)), (array([ 0.4846828 , -0.08528163], dtype=float32), np.int64(1)), (array([0.49998635, 0.00369207], dtype=float32), np.int64(1)), (array([ 0.5020095 , -0.00580185], dtype=float32), np.int64(1)), (array([0.50696516, 0.49605715], dtype=float32), np.int64(1)), (array([0.5317478 , 0.11777844], dtype=float32), np.int64(1)), (array([0.58071506, 0.31513074], dtype=float32), np.int64(1)), (array([0.6021839, 0.6193898], dtype=float32), np.int64(1)), (array([0.664925  , 0.21529113], dtype=float32), np.int64(1)), (array([0.6676229 , 0.12207424], dtype=float32), np.int64(1)), (array([0.682411  , 0.07840881], dtype=float32), np.int64(1)), (array([0.69586813, 0.29645965], dtype=float32), np.int64(1)), (array([0.73260844, 0.6974631 ], dtype=float32), np.int64(1)), (array([0.7737165 , 0.21520984], dtype=float32), np.int64(1)), (array([0.7799072 , 0.15745504], dtype=float32), np.int64(1)), (array([0.7972945 , 0.13572793], dtype=float32), np.int64(1)), (array([0.80333227, 0.32414338], dtype=float32), np.int64(1)), (array([0.8971254 , 0.37606996], dtype=float32), np.int64(1)), (array([0.92761433, 0.23499706], dtype=float32), np.int64(1)), (array([0.93364507, 0.19854422], dtype=float32), np.int64(1)), (array([0.94398886, 0.19639738], dtype=float32), np.int64(1))]

# %%
data.shape
# Out:
# (60, 88)

# %%
import numpy as np

data = np.load("./dataset/test/001.npy")
frame = data[0].reshape(44, 2)

uniq, counts = np.unique(frame, axis=0, return_counts=True)

print("unique 좌표 수:", len(uniq))
for u, c in zip(uniq, counts):
    print(u, c)
# Out:
# unique 좌표 수: 3
# [-1.251555 -1.585332] 42
# [-0.49846104 -0.03919831] 1
# [0.4984612  0.03919831] 1

# %%
import numpy as np

data = np.load("dataset/test/003.npy")
print(data.shape)

frame = data[0].reshape(44, 2)
uniq = np.unique(np.round(frame, 5), axis=0)
print("unique 좌표 수:", len(uniq))
# Out:
# (60, 88)
# unique 좌표 수: 44

# %%
for i in [0, 10, 20, 30, 40, 50]:
    frame = data[i].reshape(44, 2)
    print(i, len(np.unique(np.round(frame, 5), axis=0)))
# Out:
# 0 44
# 10 44
# 20 44
# 30 44
# 40 44
# 50 44
